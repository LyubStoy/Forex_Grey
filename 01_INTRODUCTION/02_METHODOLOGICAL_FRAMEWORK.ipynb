# %% [markdown]
# $$
# \begin{array}{l}
# \quad \textbf{Methodological Framework} \\[1.5em]
# \quad \textbf{01 --- Exchange Rate Construction} \\[0.8em]
# \quad\quad \bullet \ \text{Economy} \rightarrow \text{Inflation} \rightarrow \text{Central Bank} \rightarrow \text{Expectations} \rightarrow \text{FX} \\
# \quad\quad \bullet \ \text{Yield logic} \\
# \quad\quad \bullet \ \text{Capital flows} \\
# \quad\quad \bullet \ \text{Geopolitics} \\
# \quad\quad \bullet \ \text{Energy (very important for EUR)} \\[1.5em]
# \quad \textbf{02 --- Mathematical Modeling} \\[0.8em]
# \quad\quad \textbf{1. Data Collection, Cleaning and Construction} \\[0.5em]
# \quad\quad \textbf{2. Empirical Analysis of the Yield Spread and EUR/USD} \\[0.5em]
# \quad\quad\quad \bullet \ \text{2.1. Exploratory Analysis} \\
# \quad\quad\quad \bullet \ \text{2.2. Correlation Analysis} \\
# \quad\quad\quad \bullet \ \text{2.3. Data Transformation} \\
# \quad\quad\quad \bullet \ \text{2.4. Regime-Based (Temporal) Analysis} \\
# \quad\quad\quad \bullet \ \text{2.5. Static Linear Regression} \\
# \quad\quad\quad \bullet \ \text{2.6. Lead--Lag Analysis (Cross-Correlation)} \\
# \quad\quad\quad \bullet \ \text{2.7. Rolling Regression (Time-Varying Coefficients)} \\
# \quad\quad\quad \bullet \ \text{2.8. Mathematical and Economic Interpretation} \\[0.8em]
# \quad\quad \textbf{3. Conclusion of the Mathematical Modeling} \\[1.5em]
# \quad \textbf{03 --- Trading Strategy} \\[1em]
# \quad \textbf{04 --- Backtesting}
# \end{array}
# $$
