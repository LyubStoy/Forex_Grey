# %% [markdown]
# $$
# \begin{array}{l}
# \quad \textbf{Plan of the Mathematical Modeling} \\[1.5em]
# \quad \textbf{1. Data Collection, Cleaning and Construction} \\[0.8em]
# \quad\quad \bullet \ \text{EUR/USD daily exchange rate dataset} \\
# \quad\quad \bullet \ \text{2-year U.S. government bond yield dataset} \\
# \quad\quad \bullet \ \text{2-year German government bond yield dataset} \\
# \quad\quad \bullet \ \text{Data cleaning and preprocessing (dates, missing values, consistency)} \\
# \quad\quad \bullet \ \text{Merging datasets on a common time index} \\
# \quad\quad \bullet \ \text{Construction of the yield spread} \\[1.5em]
# \quad \textbf{2. Empirical Analysis of the Yield Spread and EUR/USD} \\[1em]
# \quad \textbf{2.1. Exploratory Analysis} \\[0.5em]
# \quad\quad \bullet \ \text{Graphical representation of EUR/USD and the yield spread (levels)} \\
# \quad\quad \bullet \ \text{Preliminary visual inspection of co-movements} \\[1em]
# \quad \textbf{2.2. Correlation Analysis} \\[0.5em]
# \quad\quad \bullet \ \text{Pearson correlation coefficient} \\
# \quad\quad \bullet \ \text{Statistical significance (p-value)} \\
# \quad\quad \bullet \ \text{Interpretation of linear dependence} \\[1em]
# \quad \textbf{2.3. Data Transformation} \\[0.5em]
# \quad\quad \bullet \ \text{Computation of first differences: } \Delta X_t = X_t - X_{t-1} \\
# \quad\quad \bullet \ \text{Standardization (Z-scores) for comparability} \\
# \quad\quad \bullet \ \text{Graphical representation of transformed series} \\
# \quad\quad \bullet \ \text{Correlation analysis on transformed data} \\[1em]
# \quad \textbf{2.4. Regime-Based (Temporal) Analysis} \\[0.5em]
# \quad\quad \bullet \ \text{Division of the sample into sub-periods (pre-COVID, COVID, post-2022)} \\
# \quad\quad \bullet \ \text{Correlation analysis within each regime} \\
# \quad\quad \bullet \ \text{Identification of structural changes} \\[1em]
# \quad \textbf{2.5. Static Linear Regression} \\[0.5em]
# \quad\quad \bullet \ \text{Estimation of the baseline model: } \\
# \quad\quad \quad \Delta \text{EUR/USD}_t = \alpha + \beta \cdot \Delta \text{Spread}_t + \varepsilon_t \\
# \quad\quad \bullet \ \text{Interpretation of coefficients} \\
# \quad\quad \bullet \ \text{Assessment of statistical significance and goodness of fit} \\[1em]
# \quad \textbf{2.6. Lead--Lag Analysis (Cross-Correlation)} \\[0.5em]
# \quad\quad \bullet \ \text{Computation of cross-correlation across multiple lags} \\
# \quad\quad \bullet \ \text{Identification of delayed effects} \\
# \quad\quad \bullet \ \text{Interpretation of temporal transmission mechanisms} \\[1em]
# \quad \textbf{2.7. Rolling Regression (Time-Varying Coefficients)} \\[0.5em]
# \quad\quad \bullet \ \text{Estimation of rolling OLS regression over a fixed window} \\
# \quad\quad \bullet \ \text{Extraction of time-varying coefficient } \beta_t \\
# \quad\quad \bullet \ \text{Analysis of temporal instability and regime dependence} \\[1em]
# \quad \textbf{2.8. Mathematical and Economic Interpretation} \\[0.5em]
# \quad\quad \bullet \ \text{Synthesis of empirical findings} \\
# \quad\quad \bullet \ \text{Assessment of explanatory power of the yield spread} \\
# \quad\quad \bullet \ \text{Discussion of limitations and additional drivers} \\[1.5em]
# \quad \textbf{3. Conclusion of the Mathematical Modeling} \\[0.8em]
# \quad\quad \bullet \ \text{Summary of key quantitative results} \\
# \quad\quad \bullet \ \text{Economic interpretation of findings} \\
# \quad\quad \bullet \ \text{Implications for modeling and trading strategies}
# \end{array}
# $$
