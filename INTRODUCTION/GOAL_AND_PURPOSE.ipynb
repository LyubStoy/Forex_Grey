# %% [markdown]
# $$
# \begin{array}{l}
# \large\textbf{This undertaking is to explain, analyze and help make decisions for the trading of EUR/USD.} \\[1em]
# \text{It includes some explanation of how the exchange rate EUR/USD moves and the reasons} \\
# \text{for even though it is impossible to completely explain the events and the factors that} \\
# \text{determine this exchange rate with 100 percent of certainty.} \\[1em]
# \text{The performance of this work is divided in 4 parts.} \\[1em]
# \textbf{The first one gives a very concise explanation for the logic of structuring of the exchange} \\
# \textbf{rate of EUR/USD. It can be called the fundamental part – it includes} \\
# \textbf{macroeconomics and geopolitics.} \\[1em]
# \textbf{The second part is the technical one. We are more interested in this one. This part is to} \\
# \textbf{confirm or to deny the affirmation of the fundamental one, to find other inner} \\
# \textbf{technical interdependences and flaws in the market, causations that are produced by} \\
# \textbf{technical the market functioning.} \\[1em]
# \textbf{The third one is how to build a strategy for taking advantage based on the technical} \\
# \textbf{analysis or trading strategy. It also implies a mathematical and statistical approach.}\\[1em]
# \textbf{The last one is to make tests before start trading.}\\[1em]
# \text{As the current and most important task in this undertaking is to build} \\
# \text{a technical mathematical project I will try first of all to achieve the first and the second parts.} \\[1em]
# \text{You can see the plan for it in the next page}
# \end{array}
# $$
