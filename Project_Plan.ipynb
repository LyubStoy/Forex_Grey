# %% [markdown]
# $$
# \begin{array}{l}
# \Large \mathbf{PROJECT\ PLAN\ OF\ BUILDING\ A\ FOREX\ WAR\ TOOL} \\[3em]
# \quad\quad\mathbf{I.} \quad \mathbf{Exchange\ Rate\ Construction} \\
# \qquad\quad\quad -\ \text{Economics reasons and logic} \\
# \qquad\qquad -\ \text{Geopolitical causes} \\[2em]
# \quad\quad\mathbf{II.} \quad \mathbf{Mathematical\ Modeling\ of\ the\ rate\ construction} \\
# \qquad\quad\quad -\ \text{Applying mathematical tools for accepting or denying the extracted logic } \\
# \qquad\quad\text{of the rate construction from the first part}\\[2em]
# \quad\quad\mathbf{III.} \quad \mathbf{Building\ a\ strategy\ for\ trading} \\
# \qquad\quad\quad -\ \text{Strategy built with mathematical models based on the conclusion made in the second part } \\
# \qquad\qquad -\ \text{Geopolitical causes} \\[2em]
# \quad\quad\mathbf{IV.} \quad \mathbf{Tests\ in\ real\ environment} \\
# \qquad\quad\quad -\ \text{Tests in the ForexTester software with real data and movements } \\
# \end{array}
# $$
